# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_excel('./sdr/SDR 2021 - Database.xlsx',sheet_name='Data for Trends')

# %%
data.head()
# Out:
#     id      Country  Year  Population  sdg1_wpc  sdg1_320pov  sdg1_oecdpov  \
# 0  AFG  Afghanistan  2000  20779957.0       NaN          NaN           NaN
# 1  AFG  Afghanistan  2001  21606992.0       NaN          NaN           NaN
# 2  AFG  Afghanistan  2002  22600774.0       NaN          NaN           NaN
# 3  AFG  Afghanistan  2003  23680871.0       NaN          NaN           NaN
# 4  AFG  Afghanistan  2004  24726689.0       NaN          NaN           NaN
#
#    sdg2_undernsh  sdg2_stuntihme  sdg2_wasteihme  ...  sdg16_safe  sdg16_prs  \
# 0            NaN           53.55           8.308  ...         NaN        NaN
# 1           47.8             NaN             NaN  ...         NaN        NaN
# 2           45.7             NaN             NaN  ...         NaN        NaN
# 3           40.7             NaN             NaN  ...         NaN        NaN
# 4           38.1             NaN             NaN  ...         NaN        NaN
#
# ...

# %%
data_year=data[(data['Year']>=2016) & (data['Year']<=2021)]

# %%
data_year['id'].value_counts()
# Out:
# TLS    6
# NLD    6
# PLW    6
# KWT    6
# BGD    6
#       ..
# LKA    6
# LCA    6
# MKD    6
# SLE    6
# SSD    6
# Name: id, Length: 193, dtype: int64

# %%
data_year=data_year.drop(['Country','Population'],axis=1)

# %%
data_pivot=data_year.pivot_table(index=['id','Year'])

# %%
data_pivot
# Out:
#           sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  sdg11_pm25  \
# id  Year
# AFG 2016            NaN          NaN          NaN          43.332      56.506
#     2017            NaN          NaN          NaN          45.101      57.273
#     2018            NaN          NaN          NaN             NaN      56.112
#     2019            NaN          NaN          NaN             NaN      54.950
#     2020            NaN          NaN          NaN             NaN         NaN
# ...                 ...          ...          ...             ...         ...
# ZWE 2016            NaN          NaN          NaN          75.633      21.920
#     2017            NaN          NaN          NaN          74.423      21.769
#     2018            NaN          NaN          NaN             NaN      21.551
#     2019            NaN          NaN          NaN             NaN      21.333
#     2020            NaN          NaN          NaN             NaN         NaN
#
# ...

# %%
score_2016=pd.read_excel('./sdr/2016GlobalIndexResults.xlsx')
score_2016
# Out:
#       ID  UNCode               CountryName  SDGI_Rank  SDGI_Score  \
# 0    SWE     752                    Sweden          1   84.529419
# 1    DNK     208                   Denmark          2   83.876137
# 2    NOR     578                    Norway          3   82.314545
# 3    FIN     246                   Finland          4   80.997849
# 4    CHE     756               Switzerland          5   80.873856
# ..   ...     ...                       ...        ...         ...
# 144  TCD     148                      Chad        145   31.790310
# 145  NER     562                     Niger        146   31.424807
# 146  COD     180          Congo, Dem. Rep.        147   31.291214
# 147  LBR     430                   Liberia        148   30.489857
# 148  CAF     140  Central African Republic        149   26.102402
#
#      GeometricRank  GeometricScore   UNReg         UnRegSub SDGIRegion  ...  \
# 0                1       83.671783  Europe  Northern Europe       OECD  ...
# ...

# %%
score_2016=score_2016[['ID','SDGI_Score']]

# %%
score_2016
# Out:
#       ID  SDGI_Score
# 0    SWE   84.529419
# 1    DNK   83.876137
# 2    NOR   82.314545
# 3    FIN   80.997849
# 4    CHE   80.873856
# ..   ...         ...
# 144  TCD   31.790310
# 145  NER   31.424807
# 146  COD   31.291214
# 147  LBR   30.489857
# 148  CAF   26.102402
#
# [149 rows x 2 columns]

# %%
score_2017=pd.read_excel('./sdr/2017GlobalIndexResults.xlsx')

# %%
score_2017
# Out:
#                   country ISO3  UN 3-digit code  Global Index Score (0-100)  \
# 0             Afghanistan  AFG                4                   46.811607
# 1                  Angola  AGO               24                   50.184246
# 2                 Albania  ALB                8                   68.902557
# 3    United Arab Emirates  ARE              784                   66.006714
# 4               Argentina  ARG               32                   72.452278
# ..                    ...  ...              ...                         ...
# 152               Vietnam  VNM              704                   67.892799
# 153           Yemen, Rep.  YEM              887                   49.803539
# 154          South Africa  ZAF              710                   61.245941
# 155                Zambia  ZMB              894                   51.075317
# 156              Zimbabwe  ZWE              716                   56.114002
#
# ...

# %%
score_2017=score_2017[['ISO3','Global Index Score (0-100)']]

# %%
score_2017
# Out:
#     ISO3  Global Index Score (0-100)
# 0    AFG                   46.811607
# 1    AGO                   50.184246
# 2    ALB                   68.902557
# 3    ARE                   66.006714
# 4    ARG                   72.452278
# ..   ...                         ...
# 152  VNM                   67.892799
# 153  YEM                   49.803539
# 154  ZAF                   61.245941
# 155  ZMB                   51.075317
# 156  ZWE                   56.114002
#
# [157 rows x 2 columns]

# %%
score_2018=pd.read_excel('./sdr/2018GlobalIndexResults.xlsx')

# %%
score_2018=score_2018[['id','Global Index Score (0-100): 2018 version']]

# %%
score_2019=pd.read_excel('./sdr/2019GlobalIndexResults.xlsx',sheet_name='SDR2019 Data')

# %%
score_2019.columns
# Out:
# Index(['Country', 'id', '2019 Global Index Score (0-100)',
#        '2019 Global Index Rank', 'Percentage missing values',
#        'Regional Score (0-100)', 'Spillover Score (0-100)', 'UN region name',
#        'Regions used for the SDG Index & Dashboard', 'Income Group in 2019',
#        ...
#        'Goal 8 Regional Score', 'Goal 9 Regional Score',
#        'Goal 10 Regional Score', 'Goal 11 Regional Score',
#        'Goal 12 Regional Score', 'Goal 13 Regional Score',
#        'Goal 14 Regional Score', 'Goal 15 Regional Score',
#        'Goal 16 Regional Score', 'Goal 17 Regional Score'],
#       dtype='object', length=486)

# %%
score_2019=score_2019[['id','2019 Global Index Score (0-100)']]

# %%
score_2019
# Out:
#       id  2019 Global Index Score (0-100)
# 0    AFG                        49.649156
# 1    AGO                        51.320358
# 2    ALB                        70.272647
# 3    AND                              NaN
# 4    ARE                        69.708919
# ..   ...                              ...
# 188  WSM                              NaN
# 189  YEM                        53.702073
# 190  ZAF                        61.480933
# 191  ZMB                        52.615084
# 192  ZWE                        59.673524
#
# [193 rows x 2 columns]

# %%
score_2020=pd.read_excel('./sdr/SDR2020Database (2).xlsx',sheet_name='SDR2020 Data')

# %%
score_2020=score_2020[['id','2020 SDG Index Score']]

# %%
score_2020
# Out:
#         id  2020 SDG Index Score
# 0      SWE             84.724063
# 1      DNK             84.558776
# 2      FIN             83.772759
# 3      FRA             81.128541
# 4      DEU             80.774386
# ..     ...                   ...
# 199  _OECD             77.304991
# 200   _LIC             52.468608
# 201  _LMIC             61.648237
# 202  _UMIC             73.240621
# 203   _HIC             77.733634
#
# [204 rows x 2 columns]

# %%
score_2016['Year']=2016
score_2016
# Out:
# <ipython-input-25-a8c637cd794f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_2016['Year']=2016
#       ID  SDGI_Score  Year
# 0    SWE   84.529419  2016
# 1    DNK   83.876137  2016
# 2    NOR   82.314545  2016
# 3    FIN   80.997849  2016
# 4    CHE   80.873856  2016
# ..   ...         ...   ...
# 144  TCD   31.790310  2016
# 145  NER   31.424807  2016
# 146  COD   31.291214  2016
# 147  LBR   30.489857  2016
# 148  CAF   26.102402  2016
#
# [149 rows x 3 columns]

# %%
score_2017['Year']=2017
# Out:
# <ipython-input-26-ecd8cd326088>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_2017['Year']=2017

# %%
score_2017
# Out:
#     ISO3  Global Index Score (0-100)  Year
# 0    AFG                   46.811607  2017
# 1    AGO                   50.184246  2017
# 2    ALB                   68.902557  2017
# 3    ARE                   66.006714  2017
# 4    ARG                   72.452278  2017
# ..   ...                         ...   ...
# 152  VNM                   67.892799  2017
# 153  YEM                   49.803539  2017
# 154  ZAF                   61.245941  2017
# 155  ZMB                   51.075317  2017
# 156  ZWE                   56.114002  2017
#
# [157 rows x 3 columns]

# %%
score_2018['Year']=2018

# %%
score_2018
# Out:
#       id  Global Index Score (0-100): 2018 version  Year
# 0    AFG                                 46.238884  2018
# 1    ALB                                 68.907867  2018
# 2    DZA                                 67.880407  2018
# 3    AND                                       NaN  2018
# 4    AGO                                 49.556541  2018
# ..   ...                                       ...   ...
# 188  VEN                                 64.000581  2018
# 189  VNM                                 69.669595  2018
# 190  YEM                                 45.657508  2018
# 191  ZMB                                 53.128743  2018
# 192  ZWE                                 58.760057  2018
#
# [193 rows x 3 columns]

# %%
score_2019['Year']=2019

# %%
score_2020['Year']=2020

# %%
score_2020
# Out:
#         id  2020 SDG Index Score  Year
# 0      SWE             84.724063  2020
# 1      DNK             84.558776  2020
# 2      FIN             83.772759  2020
# 3      FRA             81.128541  2020
# 4      DEU             80.774386  2020
# ..     ...                   ...   ...
# 199  _OECD             77.304991  2020
# 200   _LIC             52.468608  2020
# 201  _LMIC             61.648237  2020
# 202  _UMIC             73.240621  2020
# 203   _HIC             77.733634  2020
#
# [204 rows x 3 columns]

# %%
score_2016.columns=['id','score','Year']

# %%
score_2016
# Out:
#       id      score  Year
# 0    SWE  84.529419  2016
# 1    DNK  83.876137  2016
# 2    NOR  82.314545  2016
# 3    FIN  80.997849  2016
# 4    CHE  80.873856  2016
# ..   ...        ...   ...
# 144  TCD  31.790310  2016
# 145  NER  31.424807  2016
# 146  COD  31.291214  2016
# 147  LBR  30.489857  2016
# 148  CAF  26.102402  2016
#
# [149 rows x 3 columns]

# %%
data_2016=pd.merge(data_pivot,score_2016,how='left',on=['id','Year'])

# %%
score_2017.columns=['id','score','Year']

# %%
data_2017=pd.merge(data_2016,score_2017,how='left',on=['id','Year'])

# %%
score_x=data_2017['score_x'].fillna(data_2017['score_y'])

# %%
data_2017['score_x']=score_x

# %%
data_2017=data_2017.drop('score_y',axis=1)

# %%
data_2017
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
score_2018
# Out:
#       id  Global Index Score (0-100): 2018 version  Year
# 0    AFG                                 46.238884  2018
# 1    ALB                                 68.907867  2018
# 2    DZA                                 67.880407  2018
# 3    AND                                       NaN  2018
# 4    AGO                                 49.556541  2018
# ..   ...                                       ...   ...
# 188  VEN                                 64.000581  2018
# 189  VNM                                 69.669595  2018
# 190  YEM                                 45.657508  2018
# 191  ZMB                                 53.128743  2018
# 192  ZWE                                 58.760057  2018
#
# [193 rows x 3 columns]

# %%
score_2018.columns=['id','score','Year']

# %%
score_2018
# Out:
#       id      score  Year
# 0    AFG  46.238884  2018
# 1    ALB  68.907867  2018
# 2    DZA  67.880407  2018
# 3    AND        NaN  2018
# 4    AGO  49.556541  2018
# ..   ...        ...   ...
# 188  VEN  64.000581  2018
# 189  VNM  69.669595  2018
# 190  YEM  45.657508  2018
# 191  ZMB  53.128743  2018
# 192  ZWE  58.760057  2018
#
# [193 rows x 3 columns]

# %%
data_2018=pd.merge(data_2017,score_2018,how='left',on=['id','Year'])

# %%
data_2018
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
score=data_2018['score_x'].fillna(data_2018['score'])

# %%
data_2018['score_x']=score
data_2018=data_2018.drop('score',axis=1)

# %%
data_2018
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
score_2019.columns=['id','score','Year']

# %%
score_2019
# Out:
#       id      score  Year
# 0    AFG  49.649156  2019
# 1    AGO  51.320358  2019
# 2    ALB  70.272647  2019
# 3    AND        NaN  2019
# 4    ARE  69.708919  2019
# ..   ...        ...   ...
# 188  WSM        NaN  2019
# 189  YEM  53.702073  2019
# 190  ZAF  61.480933  2019
# 191  ZMB  52.615084  2019
# 192  ZWE  59.673524  2019
#
# [193 rows x 3 columns]

# %%
data_2019=pd.merge(data_2018,score_2019,how='left',on=['id','Year'])

# %%
score=data_2019['score_x'].fillna(data_2019['score'])

# %%
data_2019['score_x']=score
data_2019=data_2019.drop('score',axis=1)

# %%
data_2019
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
score_2020.columns=['id','score','Year']

# %%
data_2020=pd.merge(data_2019,score_2020,how='left',on=['id','Year'])

# %%
score=data_2020['score_x'].fillna(data_2020['score'])

# %%
data_2020['score_x']=score
data_2020=data_2020.drop('score',axis=1)

# %%
data_2020
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
data_2020.score_x.rename('score',inplace=True)
# Out:
# 0       36.504845
# 1       46.811607
# 2       46.238884
# 3       49.649156
# 4       54.224206
#           ...
# 1121    48.627514
# 1122    56.114002
# 1123    58.760057
# 1124    59.673524
# 1125    59.507829
# Name: score, Length: 1126, dtype: float64

# %%
data_2020
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
data_2020=data_2020.rename(columns={'score_x':'score'})

# %%
data_2020['score'].isna().sum()
# Out:
# 336

# %%
data_2020.shape
# Out:
# (1126, 89)

# %%
data_labels=data_2020[data_2020.score.notnull()]

# %%
data_labels
# Out:
#        id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0     AFG  2016            NaN          NaN          NaN          43.332
# 1     AFG  2017            NaN          NaN          NaN          45.101
# 2     AFG  2018            NaN          NaN          NaN             NaN
# 3     AFG  2019            NaN          NaN          NaN             NaN
# 4     AFG  2020            NaN          NaN          NaN             NaN
# ...   ...   ...            ...          ...          ...             ...
# 1121  ZWE  2016            NaN          NaN          NaN          75.633
# 1122  ZWE  2017            NaN          NaN          NaN          74.423
# 1123  ZWE  2018            NaN          NaN          NaN             NaN
# 1124  ZWE  2019            NaN          NaN          NaN             NaN
# 1125  ZWE  2020            NaN          NaN          NaN             NaN
#
#       sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
data_labels.to_csv('./data_wlabels.csv',header=True,index=False)

# %%
pd.read_csv('./data_wlabels.csv')
# Out:
#       id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0    AFG  2016            NaN          NaN          NaN          43.332
# 1    AFG  2017            NaN          NaN          NaN          45.101
# 2    AFG  2018            NaN          NaN          NaN             NaN
# 3    AFG  2019            NaN          NaN          NaN             NaN
# 4    AFG  2020            NaN          NaN          NaN             NaN
# ..   ...   ...            ...          ...          ...             ...
# 785  ZWE  2016            NaN          NaN          NaN          75.633
# 786  ZWE  2017            NaN          NaN          NaN          74.423
# 787  ZWE  2018            NaN          NaN          NaN             NaN
# 788  ZWE  2019            NaN          NaN          NaN             NaN
# 789  ZWE  2020            NaN          NaN          NaN             NaN
#
#      sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
tmp=data_labels.set_index('id').isna().sum(level=0).drop(['Year','score'],axis=1)
tmp.shape
# Out:
# (167, 86)

# %%
5*86
# Out:
# 430

# %%
tmp['null_count']=tmp.sum(axis=1)

# %%
tmp=tmp['null_count']

# %%
null_percentage=tmp/430

# %%
null_percentage.to_csv('./null_percentage.csv')

# %%
pd.read_csv('./null_percentage.csv')
# Out:
#       id  null_count
# 0    AFG    0.641860
# 1    AGO    0.616279
# 2    ALB    0.558140
# 3    ARE    0.625581
# 4    ARG    0.567442
# ..   ...         ...
# 162  VUT    0.323256
# 163  YEM    0.655814
# 164  ZAF    0.560465
# 165  ZMB    0.606977
# 166  ZWE    0.637209
#
# [167 rows x 2 columns]

# %%
data=data_labels.copy()

# %%
data['id+year']=data['id']+data['Year'].astype(str)

# %%
data=data.drop(['id','Year'],axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X=data.drop(['score','id+year'],axis=1)

# %%
y=data['score']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#       sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  sdg11_pm25  \
# 1053            NaN          NaN          NaN             NaN      19.476
# 453             NaN          NaN          NaN             NaN      90.619
# 720             NaN          NaN          NaN          98.878      15.679
# 135             NaN          NaN          NaN             NaN      12.259
# 529             NaN          NaN          NaN          77.277      25.219
# ...             ...          ...          ...             ...         ...
# 363             NaN          NaN          NaN          95.935      22.548
# 469             NaN          NaN          NaN          84.496      62.164
# 441             NaN          NaN          NaN             NaN      15.141
# 903             NaN          NaN          NaN             NaN         NaN
# 286             NaN          NaN          NaN          81.878      38.769
#
#       sdg11_rentover  sdg11_slums  sdg11_transport  sdg13_co2gcp  sdg13_ecr  \
# ...

# %%
X_test
# Out:
#       sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  sdg11_pm25  \
# 186             NaN          NaN          NaN          91.908      52.268
# 489             NaN          NaN          NaN             NaN      15.818
# 128             NaN          NaN          NaN          87.888      21.416
# 1058            NaN          NaN          NaN         100.000       9.122
# 502             NaN          NaN          NaN             NaN         NaN
# ...             ...          ...          ...             ...         ...
# 554             NaN          NaN          NaN             NaN         NaN
# 879             NaN          NaN          NaN             NaN         NaN
# 426             NaN          NaN          NaN          99.572      17.912
# 187             NaN          NaN          NaN          92.222      52.692
# 76              NaN          NaN          NaN          54.164      38.372
#
#       sdg11_rentover  sdg11_slums  sdg11_transport  sdg13_co2gcp  sdg13_ecr  \
# ...

# %%
import xgboost as xgboost

# %%
xgb=xgboost.XGBRegressor()

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_train_pred=xgb.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.028127216417532824

# %%
y_test_pred=xgb.predict(X_test)

# %%
mean_absolute_error(y_test,y_test_pred)
# Out:
# 2.2053274310746835

# %%
xgb.cv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-a295d3e5a665> in <module>
# ----> 1 xgb.cv
#
# AttributeError: 'XGBRegressor' object has no attribute 'cv'

# %%
ada=AdaBoostRegressor()

# %%
xgb.cv
# Out:
# <function xgboost.training.cv(params, dtrain, num_boost_round=10, nfold=3, stratified=False, folds=None, metrics=(), obj=None, feval=None, maximize=None, early_stopping_rounds=None, fpreproc=None, as_pandas=True, verbose_eval=None, show_stdv=True, seed=0, callbacks=None, shuffle=True)>

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
data=pd.read_csv('./data_wlabels.csv')

# %%
check=data.isna().sum()/790

# %%
len(check[check.values>0.4])
# Out:
# 60

# %%
check
# Out:
# id               0.000000
# Year             0.000000
# sdg10_adjgini    0.991139
# sdg10_elder      0.894937
# sdg10_palma      0.893671
#                    ...
# sdg9_patents     0.859494
# sdg9_rdex        0.697468
# sdg9_rdres       0.883544
# sdg9_womensci    0.930380
# score            0.000000
# Length: 89, dtype: float64

# %%
data.sdg11_pipedwat.value_counts()
# Out:
# 100.000    39
# 77.049      2
# 99.600      2
# 95.799      2
# 86.806      2
#            ..
# 99.296      1
# 37.080      1
# 79.704      1
# 20.731      1
# 92.574      1
# Name: sdg11_pipedwat, Length: 208, dtype: int64

# %%
sorted(data.isna().sum(axis=1)/89)
# Out:
# [0.19101123595505617,
#  0.19101123595505617,
#  0.20224719101123595,
#  0.20224719101123595,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.21348314606741572,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.2247191011235955,
#  0.23595505617977527,
#  0.23595505617977527,
#  0.23595505617977527,
#  0.23595505617977527,
#  0.23595505617977527,
#  0.23595505617977527,
#  0.23595505617977527,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.24719101123595505,
#  0.25842696629213485,
#  0.25842696629213485,
# ...

# %%
data.shape
# Out:
# (790, 89)

# %%
data.id.value_counts()
# Out:
# JOR    5
# JAM    5
# MDA    5
# EST    5
# SDN    5
#       ..
# FJI    2
# SOM    1
# SSD    1
# TLS    1
# BRN    1
# Name: id, Length: 167, dtype: int64

# %%
sorted(data[data.Year==2020].isna().sum(axis=1)/90)
# Out:
# [0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8111111111111111,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8222222222222222,
# ...

# %%
data=pd.read_csv('data_wlabels.csv')

# %%
data
# Out:
#       id  Year  sdg10_adjgini  sdg10_elder  sdg10_palma  sdg11_pipedwat  \
# 0    AFG  2016            NaN          NaN          NaN          43.332
# 1    AFG  2017            NaN          NaN          NaN          45.101
# 2    AFG  2018            NaN          NaN          NaN             NaN
# 3    AFG  2019            NaN          NaN          NaN             NaN
# 4    AFG  2020            NaN          NaN          NaN             NaN
# ..   ...   ...            ...          ...          ...             ...
# 785  ZWE  2016            NaN          NaN          NaN          75.633
# 786  ZWE  2017            NaN          NaN          NaN          74.423
# 787  ZWE  2018            NaN          NaN          NaN             NaN
# 788  ZWE  2019            NaN          NaN          NaN             NaN
# 789  ZWE  2020            NaN          NaN          NaN             NaN
#
#      sdg11_pm25  sdg11_rentover  sdg11_slums  sdg11_transport  ...  \
# ...

# %%
from sklearn.externals import tabne
